# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.optimizers import RMSprop

# %%
import os
from PIL import Image

# %% [markdown]
# Data Processing

# %%
target_size = (224, 224)

# Define the path to your training dataset
train_path = "corn_maize/test"

# %%
# Loop through all subdirectories in the training dataset directory
for class_dir in os.listdir(train_path):
    class_path = os.path.join(train_path, class_dir)
    print(class_path)
    if os.path.isdir(class_path):
        for filename in os.listdir(class_path):
            # Check if the file is an image
            if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
                # Construct the path to the image file
                img_path = os.path.join(class_path, filename)
                # Open the image file using PIL
                img = Image.open(img_path)
                # Resize the image to the target size
                img = img.resize(target_size)
                # Convert the image to RGB
                img = img.convert("RGB")
                # Overwrite the original image file with the resized image
                img.save(img_path)
                print(img_path)
            else:
                continue
# Out:
# corn_maize/test\Blight
# corn_maize/test\Blight\Corn_Blight (100).jpg
# corn_maize/test\Blight\Corn_Blight (101).jpg
# corn_maize/test\Blight\Corn_Blight (102).jpg
# corn_maize/test\Blight\Corn_Blight (103).jpg
# corn_maize/test\Blight\Corn_Blight (104).jpg
# corn_maize/test\Blight\Corn_Blight (105).jpg
# corn_maize/test\Blight\Corn_Blight (106).jpg
# corn_maize/test\Blight\Corn_Blight (107).jpg
# corn_maize/test\Blight\Corn_Blight (108).jpg
# corn_maize/test\Blight\Corn_Blight (109).jpg
# corn_maize/test\Blight\Corn_Blight (110).jpg
# corn_maize/test\Blight\Corn_Blight (125).jpg
# corn_maize/test\Blight\Corn_Blight (130).jpg
# corn_maize/test\Blight\Corn_Blight (134).jpg
# corn_maize/test\Blight\Corn_Blight (139).jpg
# corn_maize/test\Blight\Corn_Blight (144).jpg
# corn_maize/test\Blight\Corn_Blight (147).jpg
# corn_maize/test\Blight\Corn_Blight (162).jpg
# corn_maize/test\Blight\Corn_Blight (165).jpg
# corn_maize/test\Blight\Corn_Blight (175).jpg
# corn_maize/test\Blight\Corn_Blight (176).jpg
# corn_maize/test\Blight\Corn_Blight (178).jpg
# corn_maize/test\Blight\Corn_Blight (204).jpg
# corn_maize/test\Blight\Corn_Blight (208).jpg
# corn_maize/test\Blight\Corn_Blight (246).jpg
# corn_maize/test\Blight\Corn_Blight (259).jpg
# corn_maize/test\Blight\Corn_Blight (264).jpg
# corn_maize/test\Blight\Corn_Blight (275).jpg
# corn_maize/test\Blight\Corn_Blight (284).jpg
# corn_maize/test\Blight\Corn_Blight (286).jpg
# corn_maize/test\Blight\Corn_Blight (303).jpg
# corn_maize/test\Blight\Corn_Blight (304).jpg
# corn_maize/test\Blight\Corn_Blight (307).jpg
# corn_maize/test\Blight\Corn_Blight (309).jpg
# corn_maize/test\Blight\Corn_Blight (317).jpg
# corn_maize/test\Blight\Corn_Blight (323).jpg
# corn_maize/test\Blight\Corn_Blight (339).jpg
# corn_maize/test\Blight\Corn_Blight (348).jpg
# corn_maize/test\Blight\Corn_Blight (384).jpg
# corn_maize/test\Blight\Corn_Blight (399).jpg
# corn_maize/test\Blight\Corn_Blight (404).jpg
# corn_maize/test\Blight\Corn_Blight (415).jpg
# corn_maize/test\Blight\Corn_Blight (422).jpg
# corn_maize/test\Blight\Corn_Blight (423).jpg
# corn_maize/test\Blight\Corn_Blight (433).jpg
# corn_maize/test\Blight\Corn_Blight (438).jpg
# corn_maize/test\Blight\Corn_Blight (439).jpg
# corn_maize/test\Blight\Corn_Blight (540).jpg
# corn_maize/test\Blight\Corn_Blight (541).jpg
# corn_maize/test\Blight\Corn_Blight (542).jpg
# corn_maize/test\Blight\Corn_Blight (550).jpg
# corn_maize/test\Blight\Corn_Blight (557).jpg
# corn_maize/test\Blight\Corn_Blight (561).jpg
# corn_maize/test\Blight\Corn_Blight (580).jpg
# corn_maize/test\Blight\Corn_Blight (582).jpg
# corn_maize/test\Blight\Corn_Blight (591).jpg
# corn_maize/test\Blight\Corn_Blight (597).jpg
# corn_maize/test\Blight\Corn_Blight (600).jpg
# corn_maize/test\Blight\Corn_Blight (601).jpg
# corn_maize/test\Blight\Corn_Blight (677).jpg
# corn_maize/test\Blight\Corn_Blight (678).jpg
# corn_maize/test\Blight\Corn_Blight (703).jpg
# corn_maize/test\Blight\Corn_Blight (709).jpg
# corn_maize/test\Blight\Corn_Blight (713).jpg
# corn_maize/test\Blight\Corn_Blight (718).jpg
# corn_maize/test\Blight\Corn_Blight (720).jpg
# corn_maize/test\Blight\Corn_Blight (723).jpg
# corn_maize/test\Blight\Corn_Blight (735).jpg
# corn_maize/test\Blight\Corn_Blight (743).jpg
# corn_maize/test\Blight\Corn_Blight (754).jpg
# corn_maize/test\Blight\Corn_Blight (99).jpg
# corn_maize/test\Common_Rust
# corn_maize/test\Common_Rust\Corn_Common_Rust (1).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (10).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (11).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (12).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (13).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (14).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (15).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (16).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (17).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (18).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (19).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (2).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (20).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (21).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (22).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (23).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (24).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (25).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (26).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (27).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (28).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (29).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (3).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (30).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (31).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (32).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (33).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (34).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (35).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (36).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (37).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (38).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (39).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (4).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (40).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (41).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (42).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (43).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (44).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (45).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (46).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (47).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (48).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (49).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (5).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (50).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (51).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (52).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (53).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (54).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (55).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (56).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (57).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (58).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (59).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (6).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (60).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (61).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (62).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (63).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (64).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (65).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (66).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (67).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (68).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (69).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (7).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (70).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (71).jpg
# corn_maize/test\Common_Rust\Corn_Common_Rust (8).jpg
# corn_maize/test\Healthy\Corn_Health (979).jpg
# corn_maize/test\Healthy\Corn_Health (980).jpg
# corn_maize/test\Healthy\Corn_Health (981).jpg
# corn_maize/test\Healthy\Corn_Health (983).jpg
# corn_maize/test\Healthy\Corn_Health (984).jpg
# corn_maize/test\Healthy\Corn_Health (985).jpg
# corn_maize/test\Healthy\Corn_Health (986).jpg
# corn_maize/test\Healthy\Corn_Health (987).jpg
# corn_maize/test\Healthy\Corn_Health (988).jpg
# corn_maize/test\Healthy\Corn_Health (989).jpg
# corn_maize/test\Healthy\Corn_Health (990).jpg
# corn_maize/test\Healthy\Corn_Health (991).jpg
# corn_maize/test\Healthy\Corn_Health (992).jpg
# corn_maize/test\Healthy\Corn_Health (993).jpg
# corn_maize/test\Healthy\Corn_Health (994).jpg
# corn_maize/test\Healthy\Corn_Health (995).jpg
# corn_maize/test\Healthy\Corn_Health (996).jpg
# corn_maize/test\Healthy\Corn_Health (997).jpg
# corn_maize/test\Healthy\Corn_Health (998).jpg
# corn_maize/test\Healthy\Corn_Health (999).jpg

# %%
# Define the image dimensions and number of classes
img_width, img_height = 224, 224
num_classes = 4
num_channels = 3

# %%
# Create an ImageDataGenerator for data augmentation and preprocessing
datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.3,
        zoom_range=0.3,
        horizontal_flip=True,
        validation_split=0.2)

# %%
# Generate the training and validation sets from your directory
train_generator = datagen.flow_from_directory(
        'corn_maize/train',
        target_size=(img_width, img_height),
        batch_size=16,
        class_mode='categorical',
        subset='training')
# Out:
# Found 1677 images belonging to 4 classes.

# %%
val_generator = datagen.flow_from_directory(
        'corn_maize/train',
        target_size=(img_width, img_height),
        batch_size=16,
        class_mode='categorical',
        subset='validation')
# Out:
# Found 417 images belonging to 4 classes.

# %% [markdown]
# Build Model

# %%
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
# Define your RNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# %%
# Add a flatten layer to convert the output of the convolutional layers into a 1D array
model.add(Flatten())

# Add a dense layer with 512 units and relu activation
model.add(Dense(512, activation='relu'))

# Add an output layer with a softmax activation and two output units (for the two classes)
model.add(Dense(num_classes, activation='softmax'))

# Compile the model with categorical cross-entropy loss, RMSprop optimizer, and accuracy metric
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# Print the summary of the model
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 222, 222, 32)      896
#
#  max_pooling2d_10 (MaxPooli  (None, 111, 111, 32)      0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 109, 109, 64)      18496
#
#  max_pooling2d_11 (MaxPooli  (None, 54, 54, 64)        0
#  ng2D)
#
#  conv2d_12 (Conv2D)          (None, 52, 52, 128)       73856
#
#  max_pooling2d_12 (MaxPooli  (None, 26, 26, 128)       0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 24, 24, 256)       295168
#
#  max_pooling2d_13 (MaxPooli  (None, 12, 12, 256)       0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (None, 10, 10, 256)       590080
#
#  max_pooling2d_14 (MaxPooli  (None, 5, 5, 256)         0
#  ng2D)
#
#  flatten_2 (Flatten)         (None, 6400)              0
#
#  dense_4 (Dense)             (None, 512)               3277312
#
#  dense_5 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 4257860 (16.24 MB)
# Trainable params: 4257860 (16.24 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
batch_size = 16
train_steps = int(np.ceil(train_generator.samples / batch_size))
val_steps = int(np.ceil(val_generator.samples / batch_size))

# Train your model
history = model.fit(train_generator,
                    epochs=2,
                    validation_data=val_generator,
                    steps_per_epoch=np.ceil(train_generator.samples / train_generator.batch_size),
                    validation_steps=np.ceil(val_generator.samples / val_generator.batch_size))
# Out:
# Epoch 1/2
# 105/105 [==============================] - 304s 3s/step - loss: 1.2354 - accuracy: 0.5069 - val_loss: 0.6233 - val_accuracy: 0.8249
# Epoch 2/2
# 105/105 [==============================] - 247s 2s/step - loss: 0.6726 - accuracy: 0.7537 - val_loss: 0.4025 - val_accuracy: 0.8369

# %%
# Generate predictions for the test set
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
        'corn_maize/test',
        target_size=(img_width, img_height),
        batch_size=16,
        class_mode=None,
        shuffle=False)
# Out:
# Found 2094 images belonging to 4 classes.

# %%
y_pred = model.predict(test_generator)
y_pred = np.argmax(y_pred, axis=1) # Convert from one-hot encoding to class labels
# Out:
# 131/131 [==============================] - 87s 660ms/step

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 3, 3, 3], dtype=int64)

# %%
# Generate the true labels for the test set
y_true = test_generator.classes

# %%
# Plot the accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# Save Model

# %%
model.save('mri_model_1.h5')
# Out:
# c:\Users\jiten\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Testing

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# %%
# Define the image dimensions and number of classes
img_width, img_height = 224, 224
num_classes = 4

# %%
# Load and preprocess your uploaded image
img = image.load_img('corn_maize/test/Common_Rust/Corn_Common_Rust (2).jpg')
img = img.convert("RGB")
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img /= 255.

# %%
# Use your model to predict the class of the uploaded image
pred = model.predict(img)
print(pred)
class_idx = np.argmax(pred[0])
print(class_idx)
classes = train_generator.class_indices
print(classes)
class_label = list(classes.keys())[list(classes.values()).index(class_idx)]
print(class_label)

print("Predicted class: ", class_label)
# Out:
# 1/1 [==============================] - 0s 176ms/step
# [[9.3422741e-01 2.4781959e-02 4.0915105e-02 7.5536358e-05]]
# 0
# {'Blight': 0, 'Common-Rust': 1, 'Gray_Leaf_Spot': 2, 'Healthy': 3}
# Blight
# Predicted class:  Blight
